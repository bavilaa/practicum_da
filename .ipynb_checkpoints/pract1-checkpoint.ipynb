# %%
import pandas as pd
# %config IPCompleter.greedy=True

# %%
#loading dataset
df = pd.read_csv('Consumer_Complaints.csv')

# %%
#Checking data types
df.dtypes
# Out:
# Date received                   object
# Product                         object
# Sub-product                     object
# Issue                           object
# Sub-issue                       object
# Consumer complaint narrative    object
# Company public response         object
# Company                         object
# State                           object
# ZIP code                        object
# Tags                            object
# Consumer consent provided?      object
# Submitted via                   object
# Date sent to company            object
# Company response to consumer    object
# Timely response?                object
# Consumer disputed?              object
# Complaint ID                     int64
# dtype: object

# %%
#Sample dataset

df2 = df.sample(1000)


#df2 = df

# %%
#Transforming date into date object

df2['new_date'] = pd.to_datetime(df2['Date received'], 
                                 format='%m/%d/%Y', 
                                 errors='coerce').apply(lambda dt: dt.replace(day=1)).dt.date
df2['new_date'] = pd.to_datetime(df2['new_date'])

#Sorting

df2 = df2.sort_values(by=['new_date'],ascending=False)

#Extracting year, month, day_name
df2['year'] = pd.DatetimeIndex(df2['Date received']).year
df2['month'] = pd.DatetimeIndex(df2['Date received']).month
df2['day'] = pd.DatetimeIndex(df2['Date received']).day_name()

# %%
df2.head()
# Out:
#       Date received                                            Product  \
# 3166     09/17/2019                                    Debt collection
# 15003    09/03/2019                                    Debt collection
# 9633     09/09/2019  Credit reporting, credit repair services, or o...
# 8576     09/10/2019                                    Debt collection
# 888      09/24/2019  Credit reporting, credit repair services, or o...
#
#             Sub-product                                 Issue  \
# 3166         Other debt     Attempts to collect debt not owed
# 15003     I do not know       Written notification about debt
# 9633   Credit reporting  Incorrect information on your report
# 8576   Credit card debt       Written notification about debt
# 888    Credit reporting  Incorrect information on your report
#
#                                               Sub-issue  \
# 3166                                      Debt was paid
# 15003         Didn't receive notice of right to dispute
# 9633                Information belongs to someone else
# 8576   Didn't receive enough information to verify debt
# 888                 Information belongs to someone else
#
#                             Consumer complaint narrative  \
# 3166                                                 NaN
# 15003                                                NaN
# 9633   The following accounts are fraudulent : XXXX X...
# 8576                                                 NaN
# 888                                                  NaN
#
#                                  Company public response  \
# 3166                                                 NaN
# 15003  Company has responded to the consumer and the ...
# 9633   Company has responded to the consumer and the ...
# 8576   Company believes it acted appropriately as aut...
# 888    Company has responded to the consumer and the ...
#
#                                       Company State ZIP code  ...  \
# 3166          GC Services Limited Partnership    MN    550XX  ...
# 15003                   SCA Collections, Inc.    CA    92626  ...
# 9633   TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    760XX  ...
# 8576             Rushmore Service Center, LLC    CA    90002  ...
# 888    TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    751XX  ...
#
#       Submitted via Date sent to company Company response to consumer  \
# 3166            Web           09/17/2019      Closed with explanation
# 15003           Web           09/03/2019      Closed with explanation
# 9633            Web           09/09/2019      Closed with explanation
# 8576            Web           09/10/2019      Closed with explanation
# 888             Web           09/24/2019      Closed with explanation
#
#       Timely response? Consumer disputed? Complaint ID   new_date  year month  \
# 3166               Yes                NaN      3377169 2019-09-01  2019     9
# 15003              Yes                NaN      3361937 2019-09-01  2019     9
# 9633               Yes                NaN      3368657 2019-09-01  2019     9
# 8576               Yes                NaN      3368550 2019-09-01  2019     9
# 888                Yes                NaN      3384234 2019-09-01  2019     9
#
#            day
# 3166   Tuesday
# 15003  Tuesday
# 9633    Monday
# 8576   Tuesday
# 888    Tuesday
#
# [5 rows x 22 columns]

# %%
#Unique elements:

df_unique = df2.drop_duplicates(subset=['Product'])

# %%
df_unique
# Out:
#        Date received                                            Product  \
# 3166      09/17/2019                                    Debt collection
# 9633      09/09/2019  Credit reporting, credit repair services, or o...
# 11437     09/06/2019                        Credit card or prepaid card
# 37960     08/06/2019  Money transfer, virtual currency, or money ser...
# 18859     08/28/2019                                           Mortgage
# 40816     08/02/2019                                       Student loan
# 31759     08/13/2019                        Checking or savings account
# 103328    05/15/2019          Payday loan, title loan, or personal loan
# 92937     05/29/2019                              Vehicle loan or lease
# 628963    04/20/2017                                   Credit reporting
# 632876    04/14/2017                                      Consumer Loan
# 629078    04/20/2017                            Bank account or service
# 655238    03/10/2017                                        Credit card
# 660513    03/01/2017                                    Money transfers
# 672644    02/09/2017                                       Prepaid card
# 730405    11/01/2016                                        Payday loan
# 766178    09/01/2016                            Other financial service
#
#                            Sub-product  \
# 3166                        Other debt
# 9633                  Credit reporting
# 11437                        Gift card
# 37960     Domestic (US) money transfer
# 18859       Conventional home mortgage
# 40816   Federal student loan servicing
# 31759                 Checking account
# 103328         Personal line of credit
# 92937                             Loan
# 628963                             NaN
# 632876                    Vehicle loan
# 629078                Checking account
# 655238                             NaN
# 660513    Domestic (US) money transfer
# 672644            General purpose card
# 730405                             NaN
# 766178                 Debt settlement
#
#                                            Issue  \
# 3166           Attempts to collect debt not owed
# 9633        Incorrect information on your report
# 11437                     Trouble using the card
# 37960                  Other transaction problem
# 18859                Improper use of your report
# 40816       Dealing with your lender or servicer
# 31759                        Managing an account
# 103328              Problem when making payments
# 92937                Struggling to pay your loan
# 628963    Incorrect information on credit report
# 632876                Managing the loan or lease
# 629078     Problems caused by my funds being low
# 655238                          Billing disputes
# 660513                  Other transaction issues
# 672644   Unauthorized transactions/trans. issues
# 730405  Charged fees or interest I didn't expect
# 766178                             Fraud or scam
#
#                                                 Sub-issue  \
# 3166                                        Debt was paid
# 9633                  Information belongs to someone else
# 11437   Trouble using the card to spend money in a sto...
# 37960                                                 NaN
# 18859                                                 NaN
# 40816            Received bad information about your loan
# 31759                            Deposits and withdrawals
# 103328                                                NaN
# 92937   Lender trying to repossess or disable the vehicle
# 628963                            Information is not mine
# 632876                                                NaN
# 629078                                                NaN
# 655238                                                NaN
# 660513                                                NaN
# 672644                                                NaN
# 730405                                                NaN
# 766178                                                NaN
#
#                              Consumer complaint narrative  \
# 3166                                                  NaN
# 9633    The following accounts are fraudulent : XXXX X...
# 11437                                                 NaN
# 37960                                                 NaN
# 18859                                                 NaN
# 40816                                                 NaN
# 31759                                                 NaN
# 103328                                                NaN
# 92937                                                 NaN
# 628963                                                NaN
# 632876  In XX/XX/XXXX I began making additional paymen...
# 629078    they charged me overdraft fees a bunch of times
# 655238                                                NaN
# 660513  Using the Navy Federal Credit Union App, I acc...
# 672644  I went to withdraw {$300.00} from my rushcard ...
# 730405                                                NaN
# 766178                                                NaN
#
#                                   Company public response  \
# 3166                                                  NaN
# 9633    Company has responded to the consumer and the ...
# 11437   Company has responded to the consumer and the ...
# 37960                                                 NaN
# 18859                                                 NaN
# 40816                                                 NaN
# 31759   Company has responded to the consumer and the ...
# 103328                                                NaN
# 92937   Company has responded to the consumer and the ...
# 628963  Company has responded to the consumer and the ...
# 632876                                                NaN
# 629078  Company has responded to the consumer and the ...
# 655238  Company has responded to the consumer and the ...
# 660513  Company believes it acted appropriately as aut...
# 672644                                                NaN
# 730405  Company believes it acted appropriately as aut...
# 766178  Company believes it acted appropriately as aut...
#
#                                        Company State ZIP code  ...  \
# 3166           GC Services Limited Partnership    MN    550XX  ...
# 9633    TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    760XX  ...
# 11437                             U.S. BANCORP    AZ    85739  ...
# 37960                               SQUARE INC   NaN      NaN  ...
# 18859               Security National Mortgage    FL    33709  ...
# 40816                                AES/PHEAA    CA    952XX  ...
# 31759            PENTAGON FEDERAL CREDIT UNION    CA    94501  ...
# 103328              BBVA FINANCIAL CORPORATION    FL    32218  ...
# 92937                    WELLS FARGO & COMPANY    NC    28216  ...
# 628963     Experian Information Solutions Inc.    FL    32308  ...
# 632876    SANTANDER CONSUMER USA HOLDINGS INC.    TX      NaN  ...
# 629078           REGIONS FINANCIAL CORPORATION    KY    421XX  ...
# 655238                          CITIBANK, N.A.    CA    91709  ...
# 660513               NAVY FEDERAL CREDIT UNION    VA      NaN  ...
# 672644               Empowerment Ventures, LLC    NY    140XX  ...
# 730405                      BlueChip Financial    GA    30122  ...
# 766178        Equitable Acceptance Corporation    OH    435XX  ...
#
#        Submitted via Date sent to company     Company response to consumer  \
# 3166             Web           09/17/2019          Closed with explanation
# 9633             Web           09/09/2019          Closed with explanation
# 11437    Postal mail           09/06/2019  Closed with non-monetary relief
# 37960          Phone           08/06/2019          Closed with explanation
# 18859          Phone           09/03/2019                      In progress
# 40816            Web           08/02/2019  Closed with non-monetary relief
# 31759            Web           08/13/2019  Closed with non-monetary relief
# 103328      Referral           05/29/2019  Closed with non-monetary relief
# 92937          Phone           05/29/2019  Closed with non-monetary relief
# 628963           Web           04/20/2017  Closed with non-monetary relief
# 632876           Web           04/14/2017      Closed with monetary relief
# 629078           Web           04/20/2017          Closed with explanation
# 655238   Postal mail           03/14/2017          Closed with explanation
# 660513           Web           03/01/2017          Closed with explanation
# 672644           Web           02/13/2017          Closed with explanation
# 730405           Web           11/02/2016          Closed with explanation
# 766178         Phone           11/25/2016          Closed with explanation
#
#        Timely response? Consumer disputed? Complaint ID   new_date  year  \
# 3166                Yes                NaN      3377169 2019-09-01  2019
# 9633                Yes                NaN      3368657 2019-09-01  2019
# 11437               Yes                NaN      3366094 2019-09-01  2019
# 37960               Yes                NaN      3331256 2019-08-01  2019
# 18859               Yes                NaN      3356841 2019-08-01  2019
# 40816               Yes                NaN      3326956 2019-08-01  2019
# 31759               Yes                NaN      3339762 2019-08-01  2019
# 103328              Yes                NaN      3249058 2019-05-01  2019
# 92937               Yes                NaN      3257111 2019-05-01  2019
# 628963              Yes                 No      2445413 2017-04-01  2017
# 632876              Yes                 No      2436598 2017-04-01  2017
# 629078              Yes                 No      2441524 2017-04-01  2017
# 655238              Yes                 No      2381249 2017-03-01  2017
# 660513              Yes                 No      2367429 2017-03-01  2017
# 672644              Yes                Yes      2334173 2017-02-01  2017
# 730405              Yes                 No      2190232 2016-11-01  2016
# 766178              Yes                 No      2092809 2016-09-01  2016
#
#        month        day
# 3166       9    Tuesday
# 9633       9     Monday
# 11437      9     Friday
# 37960      8    Tuesday
# 18859      8  Wednesday
# 40816      8     Friday
# 31759      8    Tuesday
# 103328     5  Wednesday
# 92937      5  Wednesday
# 628963     4   Thursday
# 632876     4     Friday
# 629078     4   Thursday
# 655238     3     Friday
# 660513     3  Wednesday
# 672644     2   Thursday
# 730405    11    Tuesday
# 766178     9   Thursday
#
# [17 rows x 22 columns]
